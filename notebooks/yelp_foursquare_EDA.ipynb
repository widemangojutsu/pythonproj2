# %%
# imports
# fsq3W3IPG1TdIsnBZe/crVFRu13lwl8pXCL04C6zqevZlpQ=
import requests
import pandas as pd
import json

url = "https://data-api.foursquare.com/v1/datasets/data-query"

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
import requests
# Assuming you have a DataFrame named 'numbermobidf'
numbermobidf = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/numbermobidf.csv')
# url = "https://api.foursquare.com/v3/places/search"

# params = {
#   	"ll": "49.264215,-123.117772",
#   	"open_now": "true",
#   	"sort":"DISTANCE"
# }

# headers = {
#     "Accept": "application/json",
#     "Authorization": "fsq3W3IPG1TdIsnBZe/crVFRu13lwl8pXCL04C6zqevZlpQ="
# }
# fsq = requests.get(url, params=params, headers=headers).json()
# fsq = pd.DataFrame(fsq['results'])
# fsq

# yelp
yurl = "https://api.yelp.com/v3/businesses/search"
yheaders = {
    "Authorization": "Bearer fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx",
    "Accept": "application/json"
}

# You can customize the parameters based on the Yelp API documentation
yparams = {
    "latitude": f'{lat}',
    "longitude": f'{lon}',
    "radius": 1000
    }

params2 = {
    "term": "casino",
    "location": "Vancouver"
}

yresponse = requests.get(yurl, headers=yheaders, params=yparams)

yelpdf = yresponse.json()

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests
import pandas as pd

# Assuming you have a DataFrame named 'numbermobidf'
numbermobidf = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/numbermobidf.csv')

# Select a subset of the DataFrame for demonstration purposes
bikeLL = numbermobidf[['latitude', 'longitude']]

# Yelp API endpoint and headers
yurl = "https://api.yelp.com/v3/businesses/search"
yheaders = {
    "Authorization": "Bearer fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx",
    "Accept": "application/json"
}

# Initialize an empty list to store Yelp API results
yresults = []

# Loop through each row in the DataFrame
for index, row in bikeLL.iterrows():
    lat, lon = row['latitude'], row['longitude']

    # Parameters for the Yelp API request
    yparams = {
        "latitude": lat,
        "longitude": lon,
        "radius": 1000
    }

    # Make the Yelp API request with the provided headers
    yresponse = requests.get(yurl, params=yparams, headers=yheaders)
    yresponse.raise_for_status()  # Raise an error for bad responses

    ydata = yresponse.json()

    # Process the Yelp API results and append them to the list
    businesses = ydata.get('businesses', [])
    yresults.append({
        'Latitude': lat,
        'Longitude': lon,
        'Businesses': businesses
    })

# Create a DataFrame from the list of Yelp API results
yelp_df = pd.DataFrame(yresults)

# Display the DataFrame
print(yelp_df)

# Save the DataFrame to CSV
yelp_df.to_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_results.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[54], line 33
#      31 # Make the Yelp API request with the provided headers
#      32 yresponse = requests.get(yurl, params=yparams, headers=yheaders)
# ---> 33 yresponse.raise_for_status()  # Raise an error for bad responses
#      35 ydata = yresponse.json()
#      37 # Process the Yelp API results and append them to the list
#
# File c:\Users\myrcene\anaconda3\envs\staysharp\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.yelp.com/v3/businesses/search?latitude=49.287214&longitude=-123.11287&radius=1000

# %%
import requests
import pandas as pd

# Assuming you have a DataFrame named 'numbermobidf'
numbermobidf = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/numbermobidf.csv')

# Select a subset of the DataFrame for demonstration purposes
bikeLL = numbermobidf[['latitude', 'longitude']].head(2)

# Yelp API endpoint and headers
yurl = "https://api.yelp.com/v3/businesses/search"
yheaders = {
    "Authorization": "Bearer fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx",
    "Accept": "application/json"
}

# Initialize an empty list to store Yelp API results
yresults = []

# Loop through each row in the DataFrame
for index, row in bikeLL.iterrows():
    lat, lon = row['latitude'], row['longitude']

    # Parameters for the Yelp API request
    yparams = {
        "latitude": lat,
        "longitude": lon,
        "radius": 1000
    }

    # Make the Yelp API request with the provided headers
    yresponse = requests.get(yurl, params=yparams, headers=yheaders)
    yresponse.raise_for_status()  # Raise an error for bad responses

    ydata = yresponse.json()

    # Process the Yelp API results and append them to the list
    businesses = ydata.get('businesses', [])
    yresults.append({
        'latitude': lat,
        'longitude': lon,
        'businesses': businesses
    })

# Create a DataFrame from the list of Yelp API results
yelp_df = pd.DataFrame(yresults)

# Display the DataFrame
print(yelp_df)

# Save the DataFrame to CSV
yelp_df.to_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_results.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[63], line 33
#      31 # Make the Yelp API request with the provided headers
#      32 yresponse = requests.get(yurl, params=yparams, headers=yheaders)
# ---> 33 yresponse.raise_for_status()  # Raise an error for bad responses
#      35 ydata = yresponse.json()
#      37 # Process the Yelp API results and append them to the list
#
# File c:\Users\myrcene\anaconda3\envs\staysharp\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1016     http_error_msg = (
#    1017         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1018     )
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://api.yelp.com/v3/businesses/search?latitude=49.262487&longitude=-123.114397&radius=1000

# %%
yelp_df
# Out:
#     Latitude   Longitude                                         Businesses
# 0  49.262487 -123.114397  [{'id': '6iOAgzJ0DRZNSKA3FSrrOg', 'alias': 'la...
# 1  49.274566 -123.121817  [{'id': 'NdEPf2Ls5Ql3_nkwjqKvXA', 'alias': 'th...

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import requests
import pandas as pd

# Assuming 'numbermobidf' is a DataFrame with columns 'latitude' and 'longitude'
numbermobidf = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/numbermobidf.csv')

# Select a subset of the DataFrame for demonstration purposes
bikeLL = numbermobidf[['latitude', 'longitude']]

url = "https://api.foursquare.com/v3/places/search"
params = {
    "open_now": "true",
    "sort": "DISTANCE"
}
headers = {
    "Accept": "application/json",
    "Authorization": "fsq3W3IPG1TdIsnBZe/crVFRu13lwl8pXCL04C6zqevZlpQ="
}
# Initialize an empty list to store the results
results_list = []

# Loop through each row in the subset DataFrame
for index, row in bikeLL.iterrows():
    lat, lon = row['latitude'], row['longitude']

    # Parameters for the Foursquare API request
    params = {
        'll': f"{lat},{lon}",
        'open_now': 'true',
        'sort': 'DISTANCE'
    }

    # Make the Foursquare API request with the provided authorization header
    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()  # Raise an error for bad responses

    data = response.json()

    print(f"Response for coordinates {lat}, {lon}:", response.text)  # Debugging line

    # Extract relevant information from the response
    venues = data.get('venues', [])

    print(f"Venues for coordinates {lat}, {lon}:", venues)  # Debugging line

    for i, fsq_result in enumerate(results):
        for venue in fsq_result.get("results", []):
            results_list.append(f"{i+ 1}: {venue.get('name')}, Location: {venue.get('location')}, Distance: {venue.get('distance')}, Geocode: {venue.get('geocodes')}")

# Create a DataFrame from the list of results
results_df = pd.DataFrame(results_list)

# Display the DataFrame
print(results_df)

# Save the DataFrame to CSV
results_df.to_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/results_df.csv', index=False)
# Out:
# Response for coordinates 49.262487, -123.114397: {"results":[{"fsq_id":"4e223f06d4c0d32590f80ff4","categories":[{"id":13306,"name":"Taco Restaurant","short_name":"Tacos","plural_name":"Taco Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/taco_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":164,"geocodes":{"drop_off":{"latitude":49.263553,"longitude":-123.112904},"main":{"latitude":49.263601,"longitude":-123.112665},"roof":{"latitude":49.263601,"longitude":-123.112665}},"link":"/v3/places/4e223f06d4c0d32590f80ff4","location":{"address":"2450 Yukon St","address_extended":"at W Broadway","country":"CA","cross_street":"at W Broadway","formatted_address":"2450 Yukon St (at W Broadway), Vancouver BC V5Y 0A4","locality":"Vancouver","postcode":"V5Y 0A4","region":"BC"},"name":"La Taqueria Pinche Taco Shop","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aec909ff964a520ccc821e3","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":430,"geocodes":{"main":{"latitude":49.263724,"longitude":-123.108701},"roof":{"latitude":49.263724,"longitude":-123.108701}},"link":"/v3/places/4aec909ff964a520ccc821e3","location":{"address":"156 8th Ave W","country":"CA","cross_street":"btwn Columbia & Manitoba St","formatted_address":"156 8th Ave W (btwn Columbia & Manitoba St), Vancouver BC V5Y 1N2","locality":"Vancouver","postcode":"V5Y 1N2","region":"BC"},"name":"Milano Coffee","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"51b201d27dd249ae714ba728","categories":[{"id":13003,"name":"Bar","short_name":"Bar","plural_name":"Bars","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13029,"name":"Brewery","short_name":"Brewery","plural_name":"Breweries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/brewery_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":674,"geocodes":{"main":{"latitude":49.263877,"longitude":-123.105307},"roof":{"latitude":49.263877,"longitude":-123.105307}},"link":"/v3/places/51b201d27dd249ae714ba728","location":{"address":"15 8th Ave W","country":"CA","cross_street":"btwn Manitoba & Ontario","formatted_address":"15 8th Ave W (btwn Manitoba & Ontario), Vancouver BC V5Y 1M8","locality":"Vancouver","postcode":"V5Y 1M8","region":"BC"},"name":"33 Acres Brewing Co","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"5478ca03498e3bbc45e6ce54","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":724,"geocodes":{"drop_off":{"latitude":49.264523,"longitude":-123.104835},"main":{"latitude":49.264531,"longitude":-123.105038},"roof":{"latitude":49.264531,"longitude":-123.105038}},"link":"/v3/places/5478ca03498e3bbc45e6ce54","location":{"address":"2301 Ontario St","country":"CA","cross_street":"at 7th Ave","formatted_address":"2301 Ontario St (at 7th Ave), Vancouver BC V5T 2X5","locality":"Vancouver","postcode":"V5T 2X5","region":"BC"},"name":"Elysian Coffee","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"537e3ec8498ec730b9966b97","categories ...
# Venues for coordinates 49.262487, -123.114397: []
# Response for coordinates 49.274566, -123.121817: {"results":[{"fsq_id":"5751fda3498e4f21436b3b09","categories":[{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":66,"geocodes":{"main":{"latitude":49.27515,"longitude":-123.121436},"roof":{"latitude":49.27515,"longitude":-123.121436}},"link":"/v3/places/5751fda3498e4f21436b3b09","location":{"address":"1141 Mainland St","country":"CA","cross_street":"btwn Davie & Helmcken","formatted_address":"1141 Mainland St (btwn Davie & Helmcken), Vancouver BC V6B 5P2","locality":"Vancouver","postcode":"V6B 5P2","region":"BC"},"name":"Mister","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4e2901b5b61c41a2f8a38ab3","categories":[{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":83,"geocodes":{"main":{"latitude":49.275181,"longitude":-123.122007},"roof":{"latitude":49.275181,"longitude":-123.122007}},"link":"/v3/places/4e2901b5b61c41a2f8a38ab3","location":{"address":"1168 Hamilton St","address_extended":"# 203","country":"CA","cross_street":"btwn Davie & Helmcken St","formatted_address":"1168 Hamilton St (btwn Davie & Helmcken St), Vancouver BC V6B 2S2","locality":"Vancouver","postcode":"V6B 2S2","region":"BC"},"name":"The Flying Pig Yaletown","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4fac04c2e4b0685b5b224d9d","categories":[{"id":13276,"name":"Sushi Restaurant","short_name":"Sushi","plural_name":"Sushi Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/sushi_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":110,"geocodes":{"main":{"latitude":49.275269,"longitude":-123.120797},"roof":{"latitude":49.275269,"longitude":-123.120797}},"link":"/v3/places/4fac04c2e4b0685b5b224d9d","location":{"address":"1118 Mainland St","country":"CA","cross_street":"at Helmcken St.","formatted_address":"1118 Mainland St (at Helmcken St.), Vancouver BC V6B 2T9","locality":"Vancouver","postcode":"V6B 2T9","region":"BC"},"name":"Minami Restaurant","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa74bb8f964a520a14c20e3","categories":[{"id":13338,"name":"Seafood Restaurant","short_name":"Seafood","plural_name":"Seafood Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/seafood_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":114,"geocodes":{"main":{"latitude":49.274378,"longitude":-123.123236},"roof":{"latitude":49.274378,"longitude":-123.123236}},"link":"/v3/places/4aa74bb8f964a520a14c20e3","location":{"address":"1228 Hamilton St","address_extended":"# 405","country":"CA","cross_street":"at Drake St","formatted_address":"1228 Hamilton St (at Drake St), Vancouver BC V6B 6L2","locality":"Vancouver","postcode":"V6B 6L2","region":"BC"},"name":"Rodney's Oyster House","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"5af8880a838e59002ce2d728","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":208,"geocodes":{"drop_off":{"latitude":49.276002,"longitude":-123.119961},"main":{"latitude":49.275871,"longitude":-123.119875},"roof":{"latitude":49.275871,"longitude":-123. ...
# Venues for coordinates 49.274566, -123.121817: []
# Response for coordinates 49.279764, -123.110154: {"results":[{"fsq_id":"4aa8005bf964a520a24e20e3","categories":[{"id":13077,"name":"Belgian Restaurant","short_name":"Belgian","plural_name":"Belgian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":18,"geocodes":{"main":{"latitude":49.280213,"longitude":-123.1097},"roof":{"latitude":49.280213,"longitude":-123.1097}},"link":"/v3/places/4aa8005bf964a520a24e20e3","location":{"address":"562 Beatty St","country":"CA","cross_street":"btwn W Pender & Dunsmuir","formatted_address":"562 Beatty St (btwn W Pender & Dunsmuir), Vancouver BC V6B 2L3","locality":"Vancouver","postcode":"V6B 2L3","region":"BC"},"name":"Chambar","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"571f842a498e10fa3180d4cd","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":74,"geocodes":{"main":{"latitude":49.280306,"longitude":-123.109627},"roof":{"latitude":49.280306,"longitude":-123.109627}},"link":"/v3/places/571f842a498e10fa3180d4cd","location":{"address":"556 Beatty St","country":"CA","cross_street":"","formatted_address":"556 Beatty St, Vancouver BC V6B 2L3","locality":"Vancouver","postcode":"V6B 2L3","region":"BC"},"name":"Jam Cafe","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4ac00474f964a520779320e3","categories":[{"id":12050,"name":"Culinary School","short_name":"Culinary School","plural_name":"Culinary Schools","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/school_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":116,"geocodes":{"drop_off":{"latitude":49.280685,"longitude":-123.109303},"main":{"latitude":49.280599,"longitude":-123.109246},"roof":{"latitude":49.280599,"longitude":-123.109246}},"link":"/v3/places/4ac00474f964a520779320e3","location":{"address":"540 Beatty St","country":"CA","cross_street":"btwn Dunsmuir & Pender","formatted_address":"540 Beatty St (btwn Dunsmuir & Pender), Vancouver BC V6B 2L3","locality":"Vancouver","postcode":"V6B 2L3","region":"BC"},"name":"Dirty Apron Cooking School","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4b23212bf964a520a75324e3","categories":[{"id":10039,"name":"Music Venue","short_name":"Music Venue","plural_name":"Music Venues","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_","suffix":".png"}},{"id":10043,"name":"Theater","short_name":"Theater","plural_name":"Theaters","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":193,"geocodes":{"main":{"latitude":49.280353,"longitude":-123.112713},"roof":{"latitude":49.280353,"longitude":-123.112713}},"link":"/v3/places/4b23212bf964a520a75324e3","location":{"address":"600 Block Hamilton St","country":"CA","cross_street":"at W Georgia St","formatted_address":"600 Block Hamilton St (at W Georgia St), Vancouver BC V6B 2P1","locality":"Vancouver","postcode":"V6B 2P1","region":"BC"},"name":"Queen Elizabeth Theatre","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"54356181498e90773594c52f","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13040,"name":"Dessert Shop","short_name":"Desserts","plural_name":"Dessert Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/dessert_","suffix":".png"}},{"id":13148,"name":"French Restaurant" ...
# Venues for coordinates 49.279764, -123.110154: []
# Response for coordinates 49.260599, -123.113504: {"results":[{"fsq_id":"4e223f06d4c0d32590f80ff4","categories":[{"id":13306,"name":"Taco Restaurant","short_name":"Tacos","plural_name":"Taco Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/taco_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":330,"geocodes":{"drop_off":{"latitude":49.263553,"longitude":-123.112904},"main":{"latitude":49.263601,"longitude":-123.112665},"roof":{"latitude":49.263601,"longitude":-123.112665}},"link":"/v3/places/4e223f06d4c0d32590f80ff4","location":{"address":"2450 Yukon St","address_extended":"at W Broadway","country":"CA","cross_street":"at W Broadway","formatted_address":"2450 Yukon St (at W Broadway), Vancouver BC V5Y 0A4","locality":"Vancouver","postcode":"V5Y 0A4","region":"BC"},"name":"La Taqueria Pinche Taco Shop","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aec909ff964a520ccc821e3","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":492,"geocodes":{"main":{"latitude":49.263724,"longitude":-123.108701},"roof":{"latitude":49.263724,"longitude":-123.108701}},"link":"/v3/places/4aec909ff964a520ccc821e3","location":{"address":"156 8th Ave W","country":"CA","cross_street":"btwn Columbia & Manitoba St","formatted_address":"156 8th Ave W (btwn Columbia & Manitoba St), Vancouver BC V5Y 1N2","locality":"Vancouver","postcode":"V5Y 1N2","region":"BC"},"name":"Milano Coffee","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"551f1b46498e86217dc958e6","categories":[{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":618,"geocodes":{"drop_off":{"latitude":49.255064,"longitude":-123.115157},"main":{"latitude":49.255054,"longitude":-123.114856},"roof":{"latitude":49.255054,"longitude":-123.114856}},"link":"/v3/places/551f1b46498e86217dc958e6","location":{"address":"3382 Cambie St","country":"CA","cross_street":"18th Ave","formatted_address":"3382 Cambie St (18th Ave), Vancouver BC V5Z 2W5","locality":"Vancouver","postcode":"V5Z 2W5","region":"BC"},"name":"Rain or Shine","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"51b201d27dd249ae714ba728","categories":[{"id":13003,"name":"Bar","short_name":"Bar","plural_name":"Bars","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13029,"name":"Brewery","short_name":"Brewery","plural_name":"Breweries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/brewery_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":694,"geocodes":{"main":{"latitude":49.263877,"longitude":-123.105307},"roof":{"latitude":49.263877,"longitude":-123.105307}},"link":"/v3/places/51b201d27dd249ae714ba728","location":{"address":"15 8th Ave W","country":"CA","cross_street":"btwn Manitoba & Ontario","formatted_address":"15 8th Ave W (btwn Manitoba & Ontario), Vancouver BC V5Y 1M8","locality":"Vancouver","postcode":"V5Y 1M8","region":"BC"},"name":"33 Acres Brewing Co","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"5478ca03498e3bbc45e6ce54","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png ...
# Venues for coordinates 49.260599, -123.113504: []
# Response for coordinates 49.264215, -123.117772: {"results":[{"fsq_id":"4e223f06d4c0d32590f80ff4","categories":[{"id":13306,"name":"Taco Restaurant","short_name":"Tacos","plural_name":"Taco Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/taco_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":368,"geocodes":{"drop_off":{"latitude":49.263553,"longitude":-123.112904},"main":{"latitude":49.263601,"longitude":-123.112665},"roof":{"latitude":49.263601,"longitude":-123.112665}},"link":"/v3/places/4e223f06d4c0d32590f80ff4","location":{"address":"2450 Yukon St","address_extended":"at W Broadway","country":"CA","cross_street":"at W Broadway","formatted_address":"2450 Yukon St (at W Broadway), Vancouver BC V5Y 0A4","locality":"Vancouver","postcode":"V5Y 0A4","region":"BC"},"name":"La Taqueria Pinche Taco Shop","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aada430f964a5201f6120e3","categories":[{"id":16032,"name":"Park","short_name":"Park","plural_name":"Parks","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":581,"geocodes":{"main":{"latitude":49.266831,"longitude":-123.124538}},"link":"/v3/places/4aada430f964a5201f6120e3","location":{"address":"999 Charleson St","country":"CA","formatted_address":"999 Charleson St, Vancouver BC","locality":"Vancouver","region":"BC"},"name":"Charleson Park","related_places":{"children":[{"fsq_id":"4df55f78483bdb5e137ae217","categories":[{"id":16037,"name":"Playground","short_name":"Playground","plural_name":"Playgrounds","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_","suffix":".png"}}],"name":"Playground"}]},"timezone":"America/Vancouver"},{"fsq_id":"4aec909ff964a520ccc821e3","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":652,"geocodes":{"main":{"latitude":49.263724,"longitude":-123.108701},"roof":{"latitude":49.263724,"longitude":-123.108701}},"link":"/v3/places/4aec909ff964a520ccc821e3","location":{"address":"156 8th Ave W","country":"CA","cross_street":"btwn Columbia & Manitoba St","formatted_address":"156 8th Ave W (btwn Columbia & Manitoba St), Vancouver BC V5Y 1N2","locality":"Vancouver","postcode":"V5Y 1N2","region":"BC"},"name":"Milano Coffee","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"51b201d27dd249ae714ba728","categories":[{"id":13003,"name":"Bar","short_name":"Bar","plural_name":"Bars","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13029,"name":"Brewery","short_name":"Brewery","plural_name":"Breweries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/brewery_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":903,"geocodes":{"main":{"latitude":49.263877,"longitude":-123.105307},"roof":{"latitude":49.263877,"longitude":-123.105307}},"link":"/v3/places/51b201d27dd249ae714ba728","location":{"address":"15 8th Ave W","country":"CA","cross_street":"btwn Manitoba & Ontario","formatted_address":"15 8th Ave W (btwn Manitoba & Ontario), Vancouver BC V5Y 1M8","locality":"Vancouver","postcode":"V5Y 1M8","region":"BC"},"name":"33 Acres Brewing Co","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"537e3ec8498ec730b9966b97","categories":[{"id":13059,"name":"Juice Bar","short_name":"Juice Bar","plural_name":"Juice Bars","icon":{"pref ...
# Venues for coordinates 49.264215, -123.117772: []
# Response for coordinates 49.270877, -123.115103: {"results":[{"fsq_id":"5ce1a82d2a7ab6002b5398fc","categories":[{"id":13045,"name":"Gelato Shop","short_name":"Gelato","plural_name":"Gelato Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":503,"geocodes":{"main":{"latitude":49.275798,"longitude":-123.113785},"roof":{"latitude":49.275798,"longitude":-123.113785}},"link":"/v3/places/5ce1a82d2a7ab6002b5398fc","location":{"address":"55 Smithe St","country":"CA","cross_street":"","formatted_address":"55 Smithe St, Vancouver BC V6B 0R3","locality":"Vancouver","postcode":"V6B 0R3","region":"BC"},"name":"Passione Gelato","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa6f277f964a520964b20e3","categories":[{"id":10051,"name":"Stadium","short_name":"Stadium","plural_name":"Stadiums","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":601,"geocodes":{"main":{"latitude":49.275654,"longitude":-123.1112},"roof":{"latitude":49.27676,"longitude":-123.112083}},"link":"/v3/places/4aa6f277f964a520964b20e3","location":{"address":"777 Pacific Blvd","country":"CA","cross_street":"at Expo Blvd.","formatted_address":"777 Pacific Blvd (at Expo Blvd.), Vancouver BC V6B 4Y8","locality":"Vancouver","postcode":"V6B 4Y8","region":"BC"},"name":"BC Place","related_places":{"children":[{"fsq_id":"5c77817db9ac38002c6f3646","categories":[{"id":17097,"name":"Mobility Store","short_name":"Mobility Store","plural_name":"Mobility Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/default_","suffix":".png"}}],"name":"Cell Clinic Vancouver"},{"fsq_id":"50848435e4b06d381bab8ab0","categories":[{"id":10051,"name":"Stadium","short_name":"Stadium","plural_name":"Stadiums","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"name":"Edgewater Casino"},{"fsq_id":"4b9fd80df964a520f04337e3","categories":[{"id":10027,"name":"Museum","short_name":"Museum","plural_name":"Museums","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_","suffix":".png"}}],"name":"BC Sports Hall of Fame"},{"fsq_id":"4fd944b0e4b0ea76a6975c4c","categories":[{"id":10051,"name":"Stadium","short_name":"Stadium","plural_name":"Stadiums","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_","suffix":".png"}}],"name":"South East Lounge"}]},"timezone":"America/Vancouver"},{"fsq_id":"4cdf0d54f8a4a1431cabdbbc","categories":[{"id":17058,"name":"Beer Store","short_name":"Beer Store","plural_name":"Beer Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_","suffix":".png"}},{"id":17076,"name":"Liquor Store","short_name":"Liquor Store","plural_name":"Liquor Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":608,"geocodes":{"main":{"latitude":49.271225,"longitude":-123.106987},"roof":{"latitude":49.271225,"longitude":-123.106987}},"link":"/v3/places/4cdf0d54f8a4a1431cabdbbc","location":{"address":"1633 Manitoba St","country":"CA","cross_street":"Walter Hardwick Avenue","formatted_address":"1633 Manitoba St (Walter Hardwick Avenue), Vancouver BC V5Y 0B8","locality":"Vancouver","postcode":" ...
# Venues for coordinates 49.270877, -123.115103: []
# Response for coordinates 49.26893, -123.11813: {"results":[{"fsq_id":"4aada430f964a5201f6120e3","categories":[{"id":16032,"name":"Park","short_name":"Park","plural_name":"Parks","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":526,"geocodes":{"main":{"latitude":49.266831,"longitude":-123.124538}},"link":"/v3/places/4aada430f964a5201f6120e3","location":{"address":"999 Charleson St","country":"CA","formatted_address":"999 Charleson St, Vancouver BC","locality":"Vancouver","region":"BC"},"name":"Charleson Park","related_places":{"children":[{"fsq_id":"4df55f78483bdb5e137ae217","categories":[{"id":16037,"name":"Playground","short_name":"Playground","plural_name":"Playgrounds","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_","suffix":".png"}}],"name":"Playground"}]},"timezone":"America/Vancouver"},{"fsq_id":"4e223f06d4c0d32590f80ff4","categories":[{"id":13306,"name":"Taco Restaurant","short_name":"Tacos","plural_name":"Taco Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/taco_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":713,"geocodes":{"drop_off":{"latitude":49.263553,"longitude":-123.112904},"main":{"latitude":49.263601,"longitude":-123.112665},"roof":{"latitude":49.263601,"longitude":-123.112665}},"link":"/v3/places/4e223f06d4c0d32590f80ff4","location":{"address":"2450 Yukon St","address_extended":"at W Broadway","country":"CA","cross_street":"at W Broadway","formatted_address":"2450 Yukon St (at W Broadway), Vancouver BC V5Y 0A4","locality":"Vancouver","postcode":"V5Y 0A4","region":"BC"},"name":"La Taqueria Pinche Taco Shop","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"5751fda3498e4f21436b3b09","categories":[{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":719,"geocodes":{"main":{"latitude":49.27515,"longitude":-123.121436},"roof":{"latitude":49.27515,"longitude":-123.121436}},"link":"/v3/places/5751fda3498e4f21436b3b09","location":{"address":"1141 Mainland St","country":"CA","cross_street":"btwn Davie & Helmcken","formatted_address":"1141 Mainland St (btwn Davie & Helmcken), Vancouver BC V6B 5P2","locality":"Vancouver","postcode":"V6B 5P2","region":"BC"},"name":"Mister","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa74bb8f964a520a14c20e3","categories":[{"id":13338,"name":"Seafood Restaurant","short_name":"Seafood","plural_name":"Seafood Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/seafood_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":720,"geocodes":{"main":{"latitude":49.274378,"longitude":-123.123236},"roof":{"latitude":49.274378,"longitude":-123.123236}},"link":"/v3/places/4aa74bb8f964a520a14c20e3","location":{"address":"1228 Hamilton St","address_extended":"# 405","country":"CA","cross_street":"at Drake St","formatted_address":"1228 Hamilton St (at Drake St), Vancouver BC V6B 6L2","locality":"Vancouver","postcode":"V6B 6L2","region":"BC"},"name":"Rodney's Oyster House","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4fac04c2e4b0685b5b224d9d","categories":[{"id":13276,"name":"Sushi Restaurant","short_name":"Sushi","plural_name":"Sushi Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/sushi_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":739,"geocodes":{"main":{"latitude":49.275269,"longitude":-123.120797},"roof":{"latitude":49.275269,"longitude":-123.120797}},"link":"/v3/places/4fac04c2e4b0685b5b224d9 ...
# Venues for coordinates 49.26893, -123.11813: []
# Response for coordinates 49.271721, -123.104207: {"results":[{"fsq_id":"4e72a8b21495dffb8e949b60","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":180,"geocodes":{"main":{"latitude":49.271451,"longitude":-123.107006},"roof":{"latitude":49.271451,"longitude":-123.107006}},"link":"/v3/places/4e72a8b21495dffb8e949b60","location":{"address":"1605 Manitoba St","country":"CA","cross_street":"at Athletes Way","formatted_address":"1605 Manitoba St (at Athletes Way), Vancouver BC V5Y 0B8","locality":"Vancouver","postcode":"V5Y 0B8","region":"BC"},"name":"Terra Breads","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4cdf0d54f8a4a1431cabdbbc","categories":[{"id":17058,"name":"Beer Store","short_name":"Beer Store","plural_name":"Beer Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_","suffix":".png"}},{"id":17076,"name":"Liquor Store","short_name":"Liquor Store","plural_name":"Liquor Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":193,"geocodes":{"main":{"latitude":49.271225,"longitude":-123.106987},"roof":{"latitude":49.271225,"longitude":-123.106987}},"link":"/v3/places/4cdf0d54f8a4a1431cabdbbc","location":{"address":"1633 Manitoba St","country":"CA","cross_street":"Walter Hardwick Avenue","formatted_address":"1633 Manitoba St (Walter Hardwick Avenue), Vancouver BC V5Y 0B8","locality":"Vancouver","postcode":"V5Y 0B8","region":"BC"},"name":"Legacy Liquor Store","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"54bea64f498ec3ed3dde9a10","categories":[{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":327,"geocodes":{"drop_off":{"latitude":49.268874,"longitude":-123.102732},"main":{"latitude":49.268876,"longitude":-123.102894},"roof":{"latitude":49.268876,"longitude":-123.102894}},"link":"/v3/places/54bea64f498ec3ed3dde9a10","location":{"address":"1829 Quebec St","country":"CA","cross_street":"at E 2nd Ave","formatted_address":"1829 Quebec St (at E 2nd Ave), Vancouver BC V5T 2Z3","locality":"Vancouver","postcode":"V5T 2Z3","region":"BC"},"name":"Earnest Ice Cream","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4ab2c5fbf964a520446c20e3","categories":[{"id":13029,"name":"Brewery","short_name":"Brewery","plural_name":"Breweries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/brewery_","suffix":".png"}},{"id":13064,"name":"Pizzeria","short_name":"Pizza","plural_name":"Pizzerias","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/pizza_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":491,"geocodes":{"main":{"latitude":49.26727,"longitude":-123.103568},"roof":{"latitude":49.26727,"longitude":-123.103568}},"link":"/v3/places/4ab2c5fbf964a520446c20e3","location":{"address":"54B 4th Ave E","country":"CA","cross_street":"btwn Ontario & Quebec","formatted_address":"54B 4th Ave E (btwn Ontario & Quebec), Vancouver BC V5T 1E8","locality":"Vancouver","postcode":"V5T 1E8","region":"BC"},"name":"R & B Brewing Inc","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"5b7882e95455b2002c6abf1c","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon" ...
# Venues for coordinates 49.271721, -123.104207: []
# Response for coordinates 49.287214, -123.11287: {"results":[{"fsq_id":"4aa7f561f964a520384e20e3","categories":[{"id":13276,"name":"Sushi Restaurant","short_name":"Sushi","plural_name":"Sushi Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/sushi_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":81,"geocodes":{"main":{"latitude":49.286766,"longitude":-123.112205},"roof":{"latitude":49.286766,"longitude":-123.112205}},"link":"/v3/places/4aa7f561f964a520384e20e3","location":{"address":"200 Granville St","address_extended":"# 70","country":"CA","cross_street":"West Cordova Street","formatted_address":"200 Granville St (West Cordova Street), Vancouver BC V6C 1S4","locality":"Vancouver","postcode":"V6C 1S4","region":"BC"},"name":"Miku","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4ac7ad6cf964a52008b920e3","categories":[{"id":17062,"name":"Chocolate Store","short_name":"Chocolate Store","plural_name":"Chocolate Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/candystore_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":204,"geocodes":{"main":{"latitude":49.286458,"longitude":-123.115424},"roof":{"latitude":49.286458,"longitude":-123.115424}},"link":"/v3/places/4ac7ad6cf964a52008b920e3","location":{"address":"863 Hastings St W","country":"CA","cross_street":"at Hornby St.","formatted_address":"863 Hastings St W (at Hornby St.), Vancouver BC V6C 3N9","locality":"Vancouver","postcode":"V6C 3N9","region":"BC"},"name":"Mink a Chocolate Cafe  Ltd","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"626590fd7335471b48e4ed8d","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":216,"geocodes":{"drop_off":{"latitude":49.285888,"longitude":-123.114773},"main":{"latitude":49.285619,"longitude":-123.114947},"roof":{"latitude":49.285619,"longitude":-123.114947}},"link":"/v3/places/626590fd7335471b48e4ed8d","location":{"address":"740 Hastings St W","country":"CA","cross_street":"","formatted_address":"740 Hastings St W, Vancouver BC V6C 1A3","locality":"Vancouver","postcode":"V6C 1A3","region":"BC"},"name":"Breka Bakery & Café","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4c23f9faf3859c74e2d66488","categories":[{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13236,"name":"Italian Restaurant","short_name":"Italian","plural_name":"Italian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":257,"geocodes":{"main":{"latitude":49.287889,"longitude":-123.116277},"roof":{"latitude":49.287889,"longitude":-123.116277}},"link":"/v3/places/4c23f9faf3859c74e2d66488","location":{"address":"1001 Cordova St W","country":"CA","cross_street":"at Burrard St","formatted_address":"1001 Cordova St W (at Burrard St), Vancouver BC V6C 0B7","locality":"Vancouver","postcode":"V6C 0B7","region":"BC"},"name":"Bella Gelateria","related_places":{"children":[]},"timezone":"America/Vancouver"},{"fsq_id":"5075f7b9f2e73b925f6431ef","categories":[{"id":10000,"name":"Arts and Entertainment","short_name":"Arts & Entertainment","plural_name":"Arts and Entertainment","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":276,"geocodes":{"main":{"latitude":49.289031,"longitude":-123.110613},"roof":{"latitude":49.289031,"longitude":-123.110613}},"link":"/v3/places/5075f7b9f2e73b925f6431ef","location":{"address":"999 Canada Pl Way","address_extended":"# 201","country":"CA","formatted_address":"999 Canada Pl Wa ...
# Venues for coordinates 49.287214, -123.11287: []
# Response for coordinates 49.282409, -123.118541: {"results":[{"fsq_id":"4aa6f2c7f964a5209b4b20e3","categories":[{"id":10004,"name":"Art Gallery","short_name":"Art Gallery","plural_name":"Art Galleries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":146,"geocodes":{"main":{"latitude":49.282925,"longitude":-123.12041},"roof":{"latitude":49.28299,"longitude":-123.120645}},"link":"/v3/places/4aa6f2c7f964a5209b4b20e3","location":{"address":"750 Hornby St","country":"CA","cross_street":"btwn Robson & W Georgia St.","formatted_address":"750 Hornby St (btwn Robson & W Georgia St.), Vancouver BC V6Z 2H7","locality":"Vancouver","postcode":"V6Z 2H7","region":"BC"},"name":"Vancouver Art Gallery","related_places":{"children":[{"fsq_id":"5b9c6998c9f907002ca6f2b2","categories":[{"id":16041,"name":"Plaza","short_name":"Plaza","plural_name":"Plazas","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_","suffix":".png"}}],"name":"Vancouver Art Gallery North Plaza"},{"fsq_id":"5e2cbbcd1341aa000793b7f0","categories":[{"id":13027,"name":"Bistro","short_name":"Bistro","plural_name":"Bistros","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"name":"1931 Gallery Bistro"},{"fsq_id":"55841a3b498e980b8e666aee","categories":[{"id":11042,"name":"Financial Service","short_name":"Financial Service","plural_name":"Financial Services","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/financial_","suffix":".png"}},{"id":11111,"name":"Legal Service","short_name":"Legal Service","plural_name":"Legal Services","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/education/lawschool_","suffix":".png"}}],"name":"Red Payday"},{"fsq_id":"4ac7d069f964a520e7b920e3","categories":[{"id":17089,"name":"Gift Store","short_name":"Gift Store","plural_name":"Gift Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/giftshop_","suffix":".png"}}],"name":"Vancouver Art Gallery Gift Shop"}]},"timezone":"America/Vancouver"},{"fsq_id":"50c68ae6e4b0860fb515014a","categories":[{"id":13036,"name":"Tea Room","short_name":"Tea Room","plural_name":"Tea Rooms","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/tearoom_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":189,"geocodes":{"main":{"latitude":49.283854,"longitude":-123.116987},"roof":{"latitude":49.283854,"longitude":-123.116987}},"link":"/v3/places/50c68ae6e4b0860fb515014a","location":{"address":"701 W Georgia St","address_extended":"Main Level","country":"CA","cross_street":"","formatted_address":"701 W Georgia St, Vancouver BC V7Y 1G5","locality":"Vancouver","postcode":"V7Y 1G5","region":"BC"},"name":"DAVIDsTEA","related_places":{"parent":{"fsq_id":"4aa7f799f964a5204c4e20e3","categories":[{"id":17114,"name":"Shopping Mall","short_name":"Mall","plural_name":"Shopping Malls","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/mall_","suffix":".png"}}],"name":"Garage Pacific Centre"}},"timezone":"America/Vancouver"},{"fsq_id":"5170656ae4b029a050dd8a49","categories":[{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":194,"geocodes":{"main":{"latitude":49.283447,"longitude":-123.116466},"roof":{"latitude":49.283447,"longitude":-123.116466}},"link":"/v3/places/5170656ae4b029a050dd8a49","location":{"address":"688 Dunsmuir St","country":"CA","cross_street":"","formatted_address":"688 Dunsmuir St, Vancouver BC V6B 1N3","locality":"Vancouver","postcode":"V6B 1N3","region":"BC"},"name":"The Keg Steakhouse + Bar","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa7f22bf964a520214e20e3","categories":[{"id":13383,"name":"Steakhouse","short_name":"Steakhouse","plural_name":"Steakhouses ...
# Venues for coordinates 49.282409, -123.118541: []
# Response for coordinates 49.287097, -123.118551: {"results":[{"fsq_id":"4fb14574e4b0e047b2ebf605","categories":[{"id":13068,"name":"American Restaurant","short_name":"American","plural_name":"American Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}},{"id":13334,"name":"Sandwich Spot","short_name":"Sandwich Spot","plural_name":"Sandwich Spots","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":9,"geocodes":{"main":{"latitude":49.287267,"longitude":-123.118901},"roof":{"latitude":49.287267,"longitude":-123.118901}},"link":"/v3/places/4fb14574e4b0e047b2ebf605","location":{"address":"1033 Pender St W","country":"CA","cross_street":"btwn Thurlow & Burrard","formatted_address":"1033 Pender St W (btwn Thurlow & Burrard), Vancouver BC V6E 2M6","locality":"Vancouver","postcode":"V6E 2M6","region":"BC"},"name":"Meat & Bread","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4c23f9faf3859c74e2d66488","categories":[{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13236,"name":"Italian Restaurant","short_name":"Italian","plural_name":"Italian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/italian_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":173,"geocodes":{"main":{"latitude":49.287889,"longitude":-123.116277},"roof":{"latitude":49.287889,"longitude":-123.116277}},"link":"/v3/places/4c23f9faf3859c74e2d66488","location":{"address":"1001 Cordova St W","country":"CA","cross_street":"at Burrard St","formatted_address":"1001 Cordova St W (at Burrard St), Vancouver BC V6C 0B7","locality":"Vancouver","postcode":"V6C 0B7","region":"BC"},"name":"Bella Gelateria","related_places":{"children":[]},"timezone":"America/Vancouver"},{"fsq_id":"4ac7ad6cf964a52008b920e3","categories":[{"id":17062,"name":"Chocolate Store","short_name":"Chocolate Store","plural_name":"Chocolate Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/candystore_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":213,"geocodes":{"main":{"latitude":49.286458,"longitude":-123.115424},"roof":{"latitude":49.286458,"longitude":-123.115424}},"link":"/v3/places/4ac7ad6cf964a52008b920e3","location":{"address":"863 Hastings St W","country":"CA","cross_street":"at Hornby St.","formatted_address":"863 Hastings St W (at Hornby St.), Vancouver BC V6C 3N9","locality":"Vancouver","postcode":"V6C 3N9","region":"BC"},"name":"Mink a Chocolate Cafe  Ltd","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4d320c5498336dcb18401ff0","categories":[{"id":13068,"name":"American Restaurant","short_name":"American","plural_name":"American Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}},{"id":13303,"name":"Mexican Restaurant","short_name":"Mexican","plural_name":"Mexican Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/mexican_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":271,"geocodes":{"main":{"latitude":49.289603,"longitude":-123.118045},"roof":{"latitude":49.289603,"longitude":-123.118045}},"link":"/v3/places/4d320c5498336dcb18401ff0","location":{"address":"1085 Canada Pl","country":"CA","cross_street":"","formatted_address":"1085 Canada Pl, Vancouver BC V6C 0C6","locality":"Vancouver","postcode":"V6C 0C6","region":"BC"},"name":"Cactus Club Cafe","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"5205bfe411d2d4fd57c20095","categories":[{"id":13003,"name":"Bar","short_name":"Bar","plural_name":"Bars","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/nightlife/pub_","suffix":".png"}},{"id":13057,"name":"Gastropub","short_name":"Gastropub","plural_name":"Gastropubs","icon ...
# Venues for coordinates 49.287097, -123.118551: []
# ...
# Venues for coordinates 49.26262, -123.2431: []
# Response for coordinates 49.278529, -123.100017: {"results":[{"fsq_id":"530e9ea1498eee5076f049a3","categories":[{"id":13034,"name":"Café","short_name":"Café","plural_name":"Cafés","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":52,"geocodes":{"drop_off":{"latitude":49.278565,"longitude":-123.099351},"main":{"latitude":49.278692,"longitude":-123.099348},"roof":{"latitude":49.278692,"longitude":-123.099348}},"link":"/v3/places/530e9ea1498eee5076f049a3","location":{"address":"213 Georgia St E","country":"CA","cross_street":"at Main St","formatted_address":"213 Georgia St E (at Main St), Vancouver BC V6A 1Z6","locality":"Vancouver","postcode":"V6A 1Z6","region":"BC"},"name":"Matchstick Coffee Roasters","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa7fa85f964a520704e20e3","categories":[{"id":13096,"name":"Cambodian Restaurant","short_name":"Cambodian","plural_name":"Cambodian Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}},{"id":13099,"name":"Chinese Restaurant","short_name":"Chinese","plural_name":"Chinese Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/asian_","suffix":".png"}},{"id":13379,"name":"Vietnamese Restaurant","short_name":"Vietnamese","plural_name":"Vietnamese Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/vietnamese_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":130,"geocodes":{"drop_off":{"latitude":49.278547,"longitude":-123.098186},"main":{"latitude":49.278403,"longitude":-123.098188},"roof":{"latitude":49.278403,"longitude":-123.098188}},"link":"/v3/places/4aa7fa85f964a520704e20e3","location":{"address":"244 E. Georgia St","country":"CA","cross_street":"at Main St","formatted_address":"244 E. Georgia St (at Main St), Vancouver BC V6A 1Z7","locality":"Vancouver","postcode":"V6A 1Z7","region":"BC"},"name":"Phnom Penh","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4dc9a94cd22d2af63302269c","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}},{"id":13034,"name":"Café","short_name":"Café","plural_name":"Cafés","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13334,"name":"Sandwich Spot","short_name":"Sandwich Spot","plural_name":"Sandwich Spots","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/deli_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":511,"geocodes":{"main":{"latitude":49.282251,"longitude":-123.104519},"roof":{"latitude":49.282251,"longitude":-123.104519}},"link":"/v3/places/4dc9a94cd22d2af63302269c","location":{"address":"315 Carrall St","country":"CA","cross_street":"btwn Cordova & Hastings","formatted_address":"315 Carrall St (btwn Cordova & Hastings), Vancouver BC V6B 2J4","locality":"Vancouver","postcode":"V6B 2J4","region":"BC"},"name":"Nelson the Seagull","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"51cfc430498e2c2303f8720d","categories":[{"id":13297,"name":"Latin American Restaurant","short_name":"Latin American","plural_name":"Latin American Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/latinamerican_","suffix":".png"}},{"id":13303,"name":"Mexican Restaurant","short_name":"Mexican","plural_name":"Mexican Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/mexican_","suffix":".png"}},{"id":13345,"name":"Spanis ...
# Venues for coordinates 49.278529, -123.100017: []
# Response for coordinates 49.282047, -123.133057: {"results":[{"fsq_id":"4c4a3fe2c8b6b71364090efb","categories":[{"id":13002,"name":"Bakery","short_name":"Bakery","plural_name":"Bakeries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bakery_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":79,"geocodes":{"main":{"latitude":49.281117,"longitude":-123.132734},"roof":{"latitude":49.281117,"longitude":-123.132734}},"link":"/v3/places/4c4a3fe2c8b6b71364090efb","location":{"address":"1160 Davie St","address_extended":"# 140","country":"CA","cross_street":"between Thurlow and Bute","formatted_address":"1160 Davie St (between Thurlow and Bute), Vancouver BC V6E 1N1","locality":"Vancouver","postcode":"V6E 1N1","region":"BC"},"name":"Cobs Bread","related_places":{"parent":{"fsq_id":"4b7daeddf964a52046ce2fe3","categories":[{"id":19014,"name":"Hotel","short_name":"Hotel","plural_name":"Hotels","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/travel/hotel_","suffix":".png"}}],"name":"Sandman Suites Vancouver on Davie"}},"timezone":"America/Vancouver"},{"fsq_id":"4ac3fa5df964a520b89d20e3","categories":[{"id":17080,"name":"Wine Store","short_name":"Wine Store","plural_name":"Wine Stores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":339,"geocodes":{"main":{"latitude":49.279501,"longitude":-123.130244},"roof":{"latitude":49.279501,"longitude":-123.130244}},"link":"/v3/places/4ac3fa5df964a520b89d20e3","location":{"address":"1034 Davie St","country":"CA","cross_street":"at Burrard St","formatted_address":"1034 Davie St (at Burrard St), Vancouver BC V6E 1M3","locality":"Vancouver","postcode":"V6E 1M3","region":"BC"},"name":"Marquis Wine Cellar","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"52c72fe5498edf109f363e18","categories":[{"id":13034,"name":"Café","short_name":"Café","plural_name":"Cafés","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}},{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":514,"geocodes":{"main":{"latitude":49.286624,"longitude":-123.133935},"roof":{"latitude":49.286624,"longitude":-123.133935}},"link":"/v3/places/52c72fe5498edf109f363e18","location":{"address":"994 Nicola St","country":"CA","cross_street":"at Nelson St","formatted_address":"994 Nicola St (at Nelson St), Vancouver BC V6G 2C8","locality":"Vancouver","postcode":"V6G 2C8","region":"BC"},"name":"Greenhorn Cafe","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aaec434f964a520346320e3","categories":[{"id":13148,"name":"French Restaurant","short_name":"French","plural_name":"French Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/french_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":567,"geocodes":{"main":{"latitude":49.282578,"longitude":-123.125234},"roof":{"latitude":49.282578,"longitude":-123.125234}},"link":"/v3/places/4aaec434f964a520346320e3","location":{"address":"100A90 Burrard St","address_extended":"# 100","country":"CA","cross_street":"Smithe St","formatted_address":"100A90 Burrard St (Smithe St), Vancouver BC V6Z 2N2","locality":"Vancouver","postcode":"V6Z 2N2","region":"BC"},"name":"Le Crocodile Restaurant","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa9ac4ff964a520cc5420e3","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13039,"name":"Deli","sh ...
# Venues for coordinates 49.282047, -123.133057: []
# Response for coordinates 49.277773, -123.114237: {"results":[{"fsq_id":"5790281f498e75e0454bf0a9","categories":[{"id":13338,"name":"Seafood Restaurant","short_name":"Seafood","plural_name":"Seafood Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/seafood_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":92,"geocodes":{"drop_off":{"latitude":49.278661,"longitude":-123.114253},"main":{"latitude":49.278557,"longitude":-123.114183},"roof":{"latitude":49.278557,"longitude":-123.114183}},"link":"/v3/places/5790281f498e75e0454bf0a9","location":{"address":"762 Cambie St","country":"CA","cross_street":"","formatted_address":"762 Cambie St, Vancouver BC V6B 2P2","locality":"Vancouver","postcode":"V6B 2P2","region":"BC"},"name":"Fanny Bay Oyster Bar & Shellfish Market","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4aa73e90f964a520754c20e3","categories":[{"id":12080,"name":"Library","short_name":"Library","plural_name":"Libraries","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/building/library_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":200,"geocodes":{"main":{"latitude":49.279513,"longitude":-123.115381}},"link":"/v3/places/4aa73e90f964a520754c20e3","location":{"address":"350 Georgia St W","country":"CA","cross_street":"btwn Homer & Hamilton","formatted_address":"350 Georgia St W (btwn Homer & Hamilton), Vancouver BC V6B 6B1","locality":"Vancouver","postcode":"V6B 6B1","region":"BC"},"name":"Vancouver Public Library","related_places":{"children":[{"fsq_id":"4c94d97421c7199cf968137f","categories":[{"id":13035,"name":"Coffee Shop","short_name":"Coffee Shop","plural_name":"Coffee Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"name":"Blenz Coffee"},{"fsq_id":"5d5f0b2596470c0008e1a051","categories":[{"id":16017,"name":"Garden","short_name":"Garden","plural_name":"Gardens","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_","suffix":".png"}}],"name":"Phillips, Hager, and North Garden"},{"fsq_id":"5a70e912a92d9857136722c2","categories":[{"id":13033,"name":"Bubble Tea Shop","short_name":"Bubble Tea","plural_name":"Bubble Tea Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/bubble_","suffix":".png"}},{"id":13034,"name":"Café","short_name":"Café","plural_name":"Cafés","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/cafe_","suffix":".png"}}],"name":"Little Bee Bubble Tea"}]},"timezone":"America/Vancouver"},{"fsq_id":"5ce1a82d2a7ab6002b5398fc","categories":[{"id":13045,"name":"Gelato Shop","short_name":"Gelato","plural_name":"Gelato Shops","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13046,"name":"Ice Cream Parlor","short_name":"Ice Cream","plural_name":"Ice Cream Parlors","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/icecream_","suffix":".png"}},{"id":13065,"name":"Restaurant","short_name":"Restaurant","plural_name":"Restaurants","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/food/default_","suffix":".png"}}],"chains":[],"closed_bucket":"VeryLikelyOpen","distance":273,"geocodes":{"main":{"latitude":49.275798,"longitude":-123.113785},"roof":{"latitude":49.275798,"longitude":-123.113785}},"link":"/v3/places/5ce1a82d2a7ab6002b5398fc","location":{"address":"55 Smithe St","country":"CA","cross_street":"","formatted_address":"55 Smithe St, Vancouver BC V6B 0R3","locality":"Vancouver","postcode":"V6B 0R3","region":"BC"},"name":"Passione Gelato","related_places":{},"timezone":"America/Vancouver"},{"fsq_id":"4b23212bf964a520a75324e3","categories":[{"id":10039,"name":"Music Venue","short_name":"Music Venue","plural_name":"Music Venues","icon":{"prefix":"https://ss3.4sqi.net/img/cate ...
# Venues for coordinates 49.277773, -123.114237: []
#                                                        0
# 0      1: La Taqueria Pinche Taco Shop, Location: {'a...
# 1      1: Milano Coffee, Location: {'address': '156 8...
# 2      1: 33 Acres Brewing Co, Location: {'address': ...
# 3      1: Elysian Coffee, Location: {'address': '2301...
# 4      1: The Juice Truck, Location: {'address': '28 ...
# ...                                                  ...
# 12395  5: Elysian Coffee, Location: {'address': '2301...
# 12396  5: Pure Bread, Location: {'address': '5 5th Av...
# 12397  5: Rain or Shine, Location: {'address': '3382 ...
# 12398  5: R & B Brewing Inc, Location: {'address': '5...
# 12399  5: Legacy Liquor Store, Location: {'address': ...
#
# [12400 rows x 1 columns]

# %%
import pandas as pd

# Load the CSV files into DataFrames
results_df = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/results_df.csv')
yelp_results_df = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_results.csv')
numbermobidf = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/numbermobidf.csv')

# Merge the DataFrames based on 'latitude' and 'longitude' in numbermobidf
merged_df = pd.merge(numbermobidf, results_df, left_on=['latitude', 'longitude'], right_on=['Latitude', 'Longitude'], how='outer')
merged_df = pd.merge(merged_df, yelp_results_df, left_on=['latitude', 'longitude'], right_on=['Latitude', 'Longitude'], how='outer')

# Display the merged DataFrame
print(merged_df)

# Save the merged DataFrame to a CSV file
merged_df.to_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/merged_results.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_43552\644477987.py in ?()
# ----> 9 import pandas as pd
#      10
#      11 # Load the CSV files into DataFrames
#      12 results_df = pd.read_csv('C:/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/results_df.csv')
#
# c:\Users\myrcene\anaconda3\envs\staysharp\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# c:\Users\myrcene\anaconda3\envs\staysharp\lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     787             self.right_join_keys,
#     788             self.join_names,
#     789             left_drop,
#     790             right_drop,
# --> 791         ) = self._get_merge_keys()
#     792
#     793         if left_drop:
#     794             self.left = self.left._drop_labels_or_levels(left_drop)
#
# c:\Users\myrcene\anaconda3\envs\staysharp\lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1265                         # Then we're either Hashable or a wrong-length arraylike,
#    1266                         #  the latter of which will raise
#    1267                         rk = cast(Hashable, rk)
#    1268                         if rk is not None:
# -> 1269                             right_keys.append(right._get_label_or_level_values(rk))
#    1270                         else:
#    1271                             # work-around for merge_asof(right_index=True)
#    1272                             right_keys.append(right.index._values)
#
# c:\Users\myrcene\anaconda3\envs\staysharp\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1840             values = self.xs(key, axis=other_axes[0])._values
#    1841         elif self._is_level_reference(key, axis=axis):
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#    1847         if values.ndim > 1:
#
# KeyError: 'Latitude'

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx

# Client ID
# yhTtQU0H7TTNY-KsT4KJhA

url = "https://api.yelp.com/v3/businesses/search?sort_by=best_match&limit=20"
headers = {
    "accept": "application/json",
    "Authorization": "fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx"
}
response = requests.get(url, headers=headers)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\myrcene\Documents\lighthouse\lighthouse\project2\pythonproj2\notebooks\yelp_foursquare_EDA.ipynb Cell 11 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=5'>6</a> url = "https://api.yelp.com/v3/businesses/search?sort_by=best_match&limit=20"
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> headers = {
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     "accept": "application/json",
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>     "Authorization": "fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx"
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> }
# ---> <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> response = requests.get(url, headers=headers)
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> print(response.text)
#
# NameError: name 'requests' is not defined

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer fVfb_wKWizfP72_5mTkeTJ3tk74QtNfMzS0AX487gOyoSMiRmzSaYoNtETMYIpN0_5fhbwn_TSyPWsSxNHXBC_tpvfaV6wM9SyKlFrUmrk9rwVmOl6_U60Djit5dZXYx",
    "Accept": "application/json"
}
# You can customize the parameters based on the Yelp API documentation
params = {
    "term": "restaurants",
    "location": "Vancouver",
    "rating": 2.5
}
params2 = {
    "term": "casino",
    "location": "Vancouver"
}
response = requests.get(url, headers=headers, params=params)
yelpdf = response.json()
yelpdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\myrcene\Documents\lighthouse\lighthouse\project2\pythonproj2\notebooks\yelp_foursquare_EDA.ipynb Cell 13 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a> params = {
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>     "term": "restaurants",
#       <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>     "location": "Vancouver",
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>     "rating": 2.5
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=10'>11</a> }
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=11'>12</a> params2 = {
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a>     "term": "casino",
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a>     "location": "Vancouver"
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a> }
# ---> <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a> response = requests.get(url, headers=headers, params=params)
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> yelpdf = response.json()
#      <a href='vscode-notebook-cell:/c%3A/Users/myrcene/Documents/lighthouse/lighthouse/project2/pythonproj2/notebooks/yelp_foursquare_EDA.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> yelpdf
#
# NameError: name 'requests' is not defined

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
fooddf = pd.DataFrame(yelpdf['businesses'])

fooddf
# Out:
#                         id                                              alias  \
# 0   NdEPf2Ls5Ql3_nkwjqKvXA                         the-flying-pig-vancouver-5
# 1   crM1idgY_glhtxXT5kERNg                                   kingyo-vancouver
# 2   sDmD24fm6R7GVSf4Jn5vdg                          alouette-bistro-vancouver
# 3   4EV_ZcQmjAmP3pmO-_nb2A                                   miku-vancouver-2
# 4   F5wxgIiZE7LYQxgqhI483A          seaport-city-seafood-restaurant-vancouver
# 5   OHMv-_cc0kmRCWV3kM44Bg                                    kosoo-vancouver
# 6   t-soDjOlN6XkySHBdhRkKA                                   forage-vancouver
# 7   JgSGpSMHbGecAXs_o1rE_g                   dinesty-dumpling-house-vancouver
# 8   GmEeIcJ9vR04kxzYgPMEgg                        guu-with-garlic-vancouver-2
# 9   uAROEz8D29elXoNxjnPrkQ                             twisted-fork-vancouver
# 10  iid0VenH7rIp3AWuyQAAHw                                   saku-vancouver-9
# 11  Ufhxnrt_OJu4jHfVTP3aRQ  fanny-bay-oyster-bar-and-shellfish-market-vanc...
# 12  WAoOGyNniFmpksKjPysagQ                        fat-mao-noodles-vancouver-2
# 13  VPqWLp9kMiZEbctCebIZUA                              medina-cafe-vancouver
# 14  yeNenSjz_HCqngGFU5d8NQ                               phnom-penh-vancouver
# 15  K1nbiOrySlw_-XG-3NmErQ                              manousheh-vancouver-4
# 16  V4w2oMsWgZSmGKbbku9lKA                     happy-noodle-house-vancouver-3
# 17  LjdbthVdtLYKSi7iVAFl0g                       jam-cafe-on-beatty-vancouver
# 18  QzZfjFBnqtBZUUFlWVCd5w                               botanist-vancouver-2
# 19  p5thThuUITUjAy8gS3sPMw                          fable-kitchen-vancouver-2
#
#                                        name  \
# 0                            The Flying Pig
# 1                                    Kingyo
# 2                           Alouette Bistro
# 3                                      Miku
# 4           Seaport City Seafood Restaurant
# 5                                     Kosoo
# 6                                    Forage
# 7                    Dinesty Dumpling House
# 8                           Guu with Garlic
# 9                              Twisted Fork
# 10                                     Saku
# 11  Fanny Bay Oyster Bar & Shellfish Market
# 12                          Fat Mao Noodles
# 13                              Medina Cafe
# 14                               Phnom Penh
# 15                               Manoush'eh
# 16                       Happy Noodle House
# 17                       Jam Cafe on Beatty
# 18                                 Botanist
# 19                            Fable Kitchen
#
#                                             image_url  is_closed  \
# 0   https://s3-media1.fl.yelpcdn.com/bphoto/1hJWeQ...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/A33fW_...      False
# 2   https://s3-media3.fl.yelpcdn.com/bphoto/9x6vYh...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/p8OUS8...      False
# 4   https://s3-media1.fl.yelpcdn.com/bphoto/suTnAZ...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/zeWsKt...      False
# 6   https://s3-media4.fl.yelpcdn.com/bphoto/spXAIe...      False
# 7   https://s3-media3.fl.yelpcdn.com/bphoto/OD368M...      False
# 8   https://s3-media1.fl.yelpcdn.com/bphoto/nmwRtl...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/HWDBDc...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/RkkU2w...      False
# 11  https://s3-media1.fl.yelpcdn.com/bphoto/1EZFex...      False
# 12  https://s3-media3.fl.yelpcdn.com/bphoto/6JlJF_...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/xEXnf7...      False
# 14  https://s3-media2.fl.yelpcdn.com/bphoto/XzbN2-...      False
# 15  https://s3-media1.fl.yelpcdn.com/bphoto/ssDIW6...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/an17cG...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/urO8_u...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/bhHwbN...      False
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/38mz3E...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-flying-pig-vancou...          1309
# 1   https://www.yelp.com/biz/kingyo-vancouver?adju...          1103
# 2   https://www.yelp.com/biz/alouette-bistro-vanco...            53
# 3   https://www.yelp.com/biz/miku-vancouver-2?adju...          2260
# 4   https://www.yelp.com/biz/seaport-city-seafood-...            32
# 5   https://www.yelp.com/biz/kosoo-vancouver?adjus...           108
# 6   https://www.yelp.com/biz/forage-vancouver?adju...           710
# 7   https://www.yelp.com/biz/dinesty-dumpling-hous...           954
# 8   https://www.yelp.com/biz/guu-with-garlic-vanco...          1060
# 9   https://www.yelp.com/biz/twisted-fork-vancouve...          1109
# 10  https://www.yelp.com/biz/saku-vancouver-9?adju...           378
# 11  https://www.yelp.com/biz/fanny-bay-oyster-bar-...           795
# 12  https://www.yelp.com/biz/fat-mao-noodles-vanco...            49
# 13  https://www.yelp.com/biz/medina-cafe-vancouver...          2608
# 14  https://www.yelp.com/biz/phnom-penh-vancouver?...          1638
# 15  https://www.yelp.com/biz/manousheh-vancouver-4...           238
# 16  https://www.yelp.com/biz/happy-noodle-house-va...            99
# 17  https://www.yelp.com/biz/jam-cafe-on-beatty-va...          1399
# 18  https://www.yelp.com/biz/botanist-vancouver-2?...           385
# 19  https://www.yelp.com/biz/fable-kitchen-vancouv...           774
#
#                                            categories  rating  \
# 0   [{'alias': 'newcanadian', 'title': 'Canadian (...     4.0
# 1   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 2   [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 3   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 4   [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.5
# 5   [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 6   [{'alias': 'newcanadian', 'title': 'Canadian (...     4.0
# 7   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 8   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 9   [{'alias': 'french', 'title': 'French'}, {'ali...     4.0
# 10       [{'alias': 'japanese', 'title': 'Japanese'}]     4.5
# 11  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.5
# 12  [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     4.5
# 13  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 14  [{'alias': 'cambodian', 'title': 'Cambodian'},...     4.0
# 15  [{'alias': 'lebanese', 'title': 'Lebanese'}, {...     5.0
# 16  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.5
# 17  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 18  [{'alias': 'newcanadian', 'title': 'Canadian (...     4.5
# 19  [{'alias': 'newcanadian', 'title': 'Canadian (...     4.5
#
#                                           coordinates transactions price  \
# 0       {'latitude': 49.27501, 'longitude': -123.122}           []    $$
# 1     {'latitude': 49.29061, 'longitude': -123.13714}           []    $$
# 2      {'latitude': 49.2853, 'longitude': -123.11829}           []   NaN
# 3   {'latitude': 49.28691753455261, 'longitude': -...           []   $$$
# 4   {'latitude': 49.263921119674905, 'longitude': ...           []   NaN
# 5     {'latitude': 49.28494, 'longitude': -123.12592}           []    $$
# 6     {'latitude': 49.28707, 'longitude': -123.12925}           []    $$
# 7   {'latitude': 49.2908176, 'longitude': -123.134...           []    $$
# 8   {'latitude': 49.290249, 'longitude': -123.1338...           []    $$
# 9   {'latitude': 49.283194, 'longitude': -123.104445}           []    $$
# 10  {'latitude': 49.289223, 'longitude': -123.132266}           []    $$
# 11  {'latitude': 49.2787525, 'longitude': -123.113...           []    $$
# 12  {'latitude': 49.2799016, 'longitude': -123.127...           []   NaN
# 13  {'latitude': 49.2804429972571, 'longitude': -1...           []    $$
# 14  {'latitude': 49.278431, 'longitude': -123.098205}           []    $$
# 15  {'latitude': 49.27667072314417, 'longitude': -...           []     $
# 16    {'latitude': 49.27664, 'longitude': -123.12578}           []    $$
# 17  {'latitude': 49.2802586, 'longitude': -123.109...           []    $$
# 18  {'latitude': 49.2883099, 'longitude': -123.116...           []   $$$
# 19  {'latitude': 49.2679331, 'longitude': -123.149...           []    $$
#
#                                              location         phone  \
# 0   {'address1': '1168 Hamilton Street', 'address2...  +16045681344
# 1   {'address1': '871 Denman Street', 'address2': ...  +16046081677
# 2   {'address1': '567 Hornby Street', 'address2': ...  +16046898862
# 3   {'address1': '200 Granville Street', 'address2...  +16045683900
# 4   {'address1': '2425 Cambie Street', 'address2':...  +16042227288
# 5   {'address1': '1128 Robson Street', 'address2':...  +16044288414
# 6   {'address1': '1300 Robson Street', 'address2':...  +16046611400
# 7   {'address1': '1719 Robson Street', 'address2':...  +16046697769
# 8   {'address1': '1698 Robson Street', 'address2':...  +16046858678
# 9   {'address1': '213 Carral Street', 'address2': ...  +16045680749
# 10  {'address1': '1588 Robson Street', 'address2':...  +17783795872
# 11  {'address1': '762 Cambie St', 'address2': '', ...  +17783799510
# 12  {'address1': '938 Helmcken Street', 'address2'...
# 13  {'address1': '780 Richards Street', 'address2'...  +16048793114
# 14  {'address1': '244 E Georgia Street', 'address2...  +16046825777
# 15  {'address1': '620 Davie Street', 'address2': '...  +16044404402
# 16  {'address1': '630 Davie Street', 'address2': N...  +16044880399
# 17  {'address1': '556 Beatty Street', 'address2': ...  +17783791992
# 18  {'address1': '1038 Canada Place', 'address2': ...  +16046955500
# 19  {'address1': '1944 W 4th Avenue', 'address2': ...  +16047321322
#
#       display_phone     distance
# 0   +1 604-568-1344  1374.066752
# 1   +1 604-608-1677  3395.565914
# 2   +1 604-689-8862  2454.076205
# 3   +1 604-568-3900  2640.567443
# 4   +1 604-222-7288   105.778230
# 5   +1 604-428-8414  2519.114420
# 6   +1 604-661-1400  2800.525167
# 7   +1 604-669-7769  3333.750598
# 8   +1 604-685-8678  3257.020397
# 9   +1 604-568-0749  2373.768869
# 10  +1 778-379-5872  3114.450620
# 11  +1 778-379-9510  1711.527841
# 12                   2013.942883
# 13  +1 604-879-3114  1909.558436
# 14  +1 604-682-5777  2132.725095
# 15  +1 604-440-4402  1640.201435
# 16  +1 604-488-0399  1642.830919
# 17  +1 778-379-1992  1946.737676
# 18  +1 604-695-5500  2755.205444
# 19  +1 604-732-1322  2435.113184

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# yelp gave me 2 more casinos results compared to the one from foursquare

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
fooddf.sort_values('rating', ascending=False).head(10)
# Out:
#                         id                                      alias  \
# 19  bgQRJLO8QFYDpCfkeOhjVA                 robba-da-matti-vancouver-2
# 13  K1nbiOrySlw_-XG-3NmErQ                      manousheh-vancouver-4
# 15  V4w2oMsWgZSmGKbbku9lKA             happy-noodle-house-vancouver-3
# 2   4EV_ZcQmjAmP3pmO-_nb2A                           miku-vancouver-2
# 3   F5wxgIiZE7LYQxgqhI483A  seaport-city-seafood-restaurant-vancouver
# 4   sDmD24fm6R7GVSf4Jn5vdg                  alouette-bistro-vancouver
# 5   OHMv-_cc0kmRCWV3kM44Bg                            kosoo-vancouver
# 6   GmEeIcJ9vR04kxzYgPMEgg                guu-with-garlic-vancouver-2
# 18  p5thThuUITUjAy8gS3sPMw                  fable-kitchen-vancouver-2
# 8   iid0VenH7rIp3AWuyQAAHw                           saku-vancouver-9
#
#                                name  \
# 19                   Robba Da Matti
# 13                       Manoush'eh
# 15               Happy Noodle House
# 2                              Miku
# 3   Seaport City Seafood Restaurant
# 4                   Alouette Bistro
# 5                             Kosoo
# 6                   Guu with Garlic
# 18                    Fable Kitchen
# 8                              Saku
#
#                                             image_url  is_closed  \
# 19  https://s3-media3.fl.yelpcdn.com/bphoto/GDxn8f...      False
# 13  https://s3-media1.fl.yelpcdn.com/bphoto/ssDIW6...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/an17cG...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/p8OUS8...      False
# 3   https://s3-media1.fl.yelpcdn.com/bphoto/suTnAZ...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/9x6vYh...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/zeWsKt...      False
# 6   https://s3-media1.fl.yelpcdn.com/bphoto/nmwRtl...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/38mz3E...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/RkkU2w...      False
#
#                                                   url  review_count  \
# 19  https://www.yelp.com/biz/robba-da-matti-vancou...            14
# 13  https://www.yelp.com/biz/manousheh-vancouver-4...           238
# 15  https://www.yelp.com/biz/happy-noodle-house-va...            99
# 2   https://www.yelp.com/biz/miku-vancouver-2?adju...          2260
# 3   https://www.yelp.com/biz/seaport-city-seafood-...            32
# 4   https://www.yelp.com/biz/alouette-bistro-vanco...            53
# 5   https://www.yelp.com/biz/kosoo-vancouver?adjus...           108
# 6   https://www.yelp.com/biz/guu-with-garlic-vanco...          1060
# 18  https://www.yelp.com/biz/fable-kitchen-vancouv...           774
# 8   https://www.yelp.com/biz/saku-vancouver-9?adju...           378
#
#                                            categories  rating  \
# 19         [{'alias': 'italian', 'title': 'Italian'}]     5.0
# 13  [{'alias': 'lebanese', 'title': 'Lebanese'}, {...     5.0
# 15  [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.5
# 2   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 3   [{'alias': 'dimsum', 'title': 'Dim Sum'}, {'al...     4.5
# 4   [{'alias': 'french', 'title': 'French'}, {'ali...     4.5
# 5   [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.5
# 6   [{'alias': 'japanese', 'title': 'Japanese'}, {...     4.5
# 18  [{'alias': 'newcanadian', 'title': 'Canadian (...     4.5
# 8        [{'alias': 'japanese', 'title': 'Japanese'}]     4.5
#
#                                           coordinates transactions price  \
# 19  {'latitude': 49.283146323514835, 'longitude': ...           []   NaN
# 13  {'latitude': 49.27667072314417, 'longitude': -...           []     $
# 15    {'latitude': 49.27664, 'longitude': -123.12578}           []    $$
# 2   {'latitude': 49.28691753455261, 'longitude': -...           []   $$$
# 3   {'latitude': 49.263921119674905, 'longitude': ...           []   NaN
# 4      {'latitude': 49.2853, 'longitude': -123.11829}           []   NaN
# 5     {'latitude': 49.28494, 'longitude': -123.12592}           []    $$
# 6   {'latitude': 49.290249, 'longitude': -123.1338...           []    $$
# 18  {'latitude': 49.2679331, 'longitude': -123.149...           []    $$
# 8   {'latitude': 49.289223, 'longitude': -123.132266}           []    $$
#
#                                              location         phone  \
# 19  {'address1': '12 Powell St', 'address2': '', '...
# 13  {'address1': '620 Davie Street', 'address2': '...  +16044404402
# 15  {'address1': '630 Davie Street', 'address2': N...  +16044880399
# 2   {'address1': '200 Granville Street', 'address2...  +16045683900
# 3   {'address1': '2425 Cambie Street', 'address2':...  +16042227288
# 4   {'address1': '567 Hornby Street', 'address2': ...  +16046898862
# 5   {'address1': '1128 Robson Street', 'address2':...  +16044288414
# 6   {'address1': '1698 Robson Street', 'address2':...  +16046858678
# 18  {'address1': '1944 W 4th Avenue', 'address2': ...  +16047321322
# 8   {'address1': '1588 Robson Street', 'address2':...  +17783795872
#
#       display_phone     distance
# 19                   2387.294542
# 13  +1 604-440-4402  1640.201435
# 15  +1 604-488-0399  1642.830919
# 2   +1 604-568-3900  2640.567443
# 3   +1 604-222-7288   105.778230
# 4   +1 604-689-8862  2454.076205
# 5   +1 604-428-8414  2519.114420
# 6   +1 604-685-8678  3257.020397
# 18  +1 604-732-1322  2435.113184
# 8   +1 778-379-5872  3114.450620
